# %% [markdown]
# # Reading and writing files

# %% [markdown]
# We have made good progress and now we can get down to the more serious task of manipulating files. This is one of the very important points concerning this training.
#
#
# N.B: Most of the files in `./data/` are files that we will use to understand how file opening works. They don't have a special purpose other than that.

# %% [markdown]
# To open/edit a file in python we use the `open()` function.
#
# This function takes as first parameter the path of the file (*relative* or *absolute*) and as second parameter the type of opening, _i.e._ reading or writing mode.
#
# A **relative path** in computing is a path that takes into account the current location. The path is **relative** to where it is called from
#
# - **Example:** _./data/data.txt_
#
# An **absolute path** is a complete path that can be read regardless of the reading location
#
# - **Example:** _/Users/becodian/Desktop/BeCode/ai-track/content/2.python/2.python_advanced/04.File-handling/data/data.txt_
#
# The best practice is to always use **relative** paths in your Python code. In this way your code can be shared **as it is** with your colleagues. An absolute path will generate an error since it exists only on your own computer.

# %%
filename = "./data/data.txt"
my_file = open(filename, "r")  # r for "read"

# %% [markdown]
# - `"r"`, for a read opening (READ).
#
# - `"w"`, for a write opening (WRITE), each time the file is opened, the content of the file is overwritten. If the file does not exist, Python creates it.
#
#     *The Python docs say that `w+` will "overwrite the existing file if the file exists". So as soon as you open a file with `w+`, it is now an empty file: it contains 0 bytes. If it used to contain data, that data has been truncated — cut off and thrown away — and now the file size is 0 bytes, so you can't read any of the data that existed before you opened the file with `w+`. If you actually wanted to read the previous data and add to it, you should use `r+` instead of `w+`* [[Source]](https://stackoverflow.com/questions/16208206/confused-by-python-file-mode-w#comment83227862_16208298)
#
#
#
# - `"a"`, for an opening in add mode at the end of the file (APPEND). If the file does not exist, Python creates it.
#
# - `"x"`, creates a new file and opens it for writing
#
# You can also append the character `+` and `b` to nearly all of the above commands. [[More info here]](https://stackabuse.com/file-handling-in-python/)

# %% [markdown]
# Like any open element, it must be closed again once the instructions have been completed. To do this, we use the `close()` method.

# %%
my_file.close()

# %%
# Let's find out what's going on there
my_file = open(filename, "r")
print(my_file.read())
my_file.close()
# Out:
# Hi everyone, I'm adding sentences to the file !

# %% [markdown]
# Another possibility of opening without closing by using a **with** statement. That's a **best practice** and you should use that as much as you can.

# %%
with open(filename, "r") as my_file:
    print(my_file.read())
# Out:
# Hi everyone, I'm adding sentences to the file !

# %% [markdown]
# Can you create a list based on the contents of this file? Each word should be an element of the list
# *(Use `.split()` for example...)*

# %%
with open(filename, "r") as my_file:
    print(my_file.read().split(" "))
# Out:
# ['Hi', 'everyone,', "I'm", 'adding', 'sentences', 'to', 'the', 'file', '!']

# %% [markdown]
# To write in a file, just **open** (existing or not), write in it and close it. We open it in mode `"w"` so that the previous data is deleted and new data can be added.

# %%
new_filename = "./data/data_new.txt"
file = open(new_filename, "w")
file.write("Hi everyone, I'm adding sentences to the file !")
file.close()

# %% [markdown]
# Can you take the content of the `data.txt` file from the `./data/` directory, capitalize all the words and write them in the file that you created just before, after the sentences you added?

# %%
# It's up to you to write the end
array = []
with open(filename, "r") as input_file:
    with open(new_filename, "a") as output_file:
        array = input_file.read().split(" ")
        for element in array:
            output_file.write(f" {element.capitalize()}")

# %% [markdown]
# ## Management of directory paths...

# %% [markdown]
# The `os` module is a library that provides a portable way of using operating system dependent functionality.
# In this chapter, we are interested in using its powerful file path handling capabilities using `os.path`.

# %%
import os

# %% [markdown]
# Each file or folder is associated with a kind of address that makes it easy to find it without errors. It is not possible to have a file with an identical name as another inside the same folder (except if the file extension is different).
#
# As said before, there are two kinds of paths: the absolute path from the root of your file system and the relative path from the folder being read.

# %% [markdown]
# By using `help` function, we can see the available methods.

# %%
help(os.path)
# Out:
# Help on module posixpath:
#
# NAME
#     posixpath - Common operations on Posix pathnames.
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/posixpath.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Instead of importing this module directly, import os and refer to
#     this module as os.path.  The "os.path" name is an alias for this
#     module on Posix systems; on other systems (e.g. Windows),
#     os.path provides the same operations in a manner specific to that
#     platform, and is an alias to another module (e.g. ntpath).
#
#     Some of this can actually be useful on non-Posix systems too, e.g.
#     for manipulation of the pathname component of URLs.
#
# FUNCTIONS
#     abspath(path)
#         Return an absolute path.
#
#     basename(p)
#         Returns the final component of a pathname
#
#     commonpath(paths)
#         Given a sequence of path names, returns the longest common sub-path.
#
#     commonprefix(m)
#         Given a list of pathnames, returns the longest common leading component
#
#     dirname(p)
#         Returns the directory component of a pathname
#
#     exists(path)
#         Test whether a path exists.  Returns False for broken symbolic links
#
#     expanduser(path)
#         Expand ~ and ~user constructions.  If user or $HOME is unknown,
#         do nothing.
#
#     expandvars(path)
#         Expand shell variables of form $var and ${var}.  Unknown variables
#         are left unchanged.
#
#     getatime(filename)
#         Return the last access time of a file, reported by os.stat().
#
#     getctime(filename)
#         Return the metadata change time of a file, reported by os.stat().
#
#     getmtime(filename)
#         Return the last modification time of a file, reported by os.stat().
#
#     getsize(filename)
#         Return the size of a file, reported by os.stat().
#
#     isabs(s)
#         Test whether a path is absolute
#
#     isdir(s)
#         Return true if the pathname refers to an existing directory.
#
#     isfile(path)
#         Test whether a path is a regular file
#
#     isjunction(path)
#         Test whether a path is a junction
#         Junctions are not a part of posix semantics
#
#     islink(path)
#         Test whether a path is a symbolic link
#
#     ismount(path)
#         Test whether a path is a mount point
#
#     join(a, *p)
#         Join two or more pathname components, inserting '/' as needed.
#         If any component is an absolute path, all previous path components
#         will be discarded.  An empty last part will result in a path that
#         ends with a separator.
#
#     lexists(path)
#         Test whether a path exists.  Returns True for broken symbolic links
#
#     normcase(s)
#         Normalize case of pathname.  Has no effect under Posix
#
#     normpath(path)
#         Normalize path, eliminating double slashes, etc.
#
#     realpath(filename, *, strict=False)
#         Return the canonical path of the specified filename, eliminating any
#         symbolic links encountered in the path.
#
#     relpath(path, start=None)
#         Return a relative version of a path
#
#     samefile(f1, f2)
#         Test whether two pathnames reference the same actual file or directory
#
#         This is determined by the device number and i-node number and
#         raises an exception if an os.stat() call on either pathname fails.
#
#     sameopenfile(fp1, fp2)
#         Test whether two open file objects reference the same file
#
#     samestat(s1, s2)
#         Test whether two stat buffers reference the same file
#
#     split(p)
#         Split a pathname.  Returns tuple "(head, tail)" where "tail" is
#         everything after the final slash.  Either part may be empty.
#
#     splitdrive(p)
#         Split a pathname into drive and path. On Posix, drive is always
#         empty.
#
#     splitext(p)
#         Split the extension from a pathname.
#
#         Extension is everything from the last dot to the end, ignoring
#         leading dots.  Returns "(root, ext)"; ext may be empty.
#
#     splitroot(p)
#         Split a pathname into drive, root and tail. On Posix, drive is always
#         empty; the root may be empty, a single slash, or two slashes. The tail
#         contains anything after the root. For example:
#
#             splitroot('foo/bar') == ('', '', 'foo/bar')
#             splitroot('/foo/bar') == ('', '/', 'foo/bar')
#             splitroot('//foo/bar') == ('', '//', 'foo/bar')
#             splitroot('///foo/bar') == ('', '/', '//foo/bar')
#
# DATA
#     __all__ = ['normcase', 'isabs', 'join', 'splitdrive', 'splitroot', 'sp...
#     altsep = None
#     curdir = '.'
#     defpath = '/bin:/usr/bin'
#     devnull = '/dev/null'
#     extsep = '.'
#     pardir = '..'
#     pathsep = ':'
#     sep = '/'
#     supports_unicode_filenames = False
#
# FILE
#     /usr/lib/python3.12/posixpath.py

# %% [markdown]
# To know your current absolute path, use `abspath('')`

# %%
# In Python a path is a string, so there are methods to manipulate it.
path = os.path.abspath("")
print(path)
print(type(path))
# Out:
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling
# <class 'str'>

# %% [markdown]
#  To get the **directory** containing a path, usr `dirname(path)`.

# %%
path_1 = os.path.dirname(path)
print(path_1)
# Out:
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced

# %% [markdown]
# To only get the file name of a path (or directory name if this is a directory), use `basename(path)`.

# %%
os.path.basename(path)
# Out:
# '04-FileHandling'

# %% [markdown]
# To add a directory, let's say `"text"` to the path, we use `join()`.
#
# The cool thing is that it is compatible across operating systems. Meaning that on Windows it will automatically add `\` between the arguments of `os.path.join`, and on Linux it will add `/`. The same code thus works on every operating system!

# %%
rep_text = os.path.join(path, "text")
print(rep_text)
# Out:
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/text

# %% [markdown]
# To retrieve all the elements of a folder as a list, you can use the `listdir()` method.

# %%
# Items are returned as a list and includes folders and hidden files.
os.listdir("../")
# Out:
# ['06-Concurrency',
#  '08-Typing',
#  'README.md',
#  '04-FileHandling',
#  '01-OOP',
#  '02-ExceptionHandling',
#  '07-Decorators',
#  '10-UnitTesting',
#  '03-Regex',
#  '09-DataStructures',
#  '05-Scraping']

# %% [markdown]
# ### How to display all the elements of a folder as well as its child folders?
#
# With the `walk()` function:
#
# ```
# walk(top, topdown=True, onerror=None, followlinks=False)
# ```

# %%
folder_path = os.path.abspath("./")
print(folder_path)

for path, dirs, files in os.walk(folder_path):
    for filename in files:
        print(os.path.join(path, filename))
# Out:
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/file-handling.ipynb
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX09.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/mail.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX01.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX90.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX89.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX75.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX06.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/data.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX07.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX87.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/L'équipe,du sport en continu..html
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX83.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX05.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX08.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX74.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/final.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX94.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/write.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/comptagevelo2017.xlsx
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/weather_2012.csv
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/weather_2017.csv
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/data_new.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/comptagevelo2017.csv
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX79.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/html_inpage_rendering_lib_200_243.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/0d3f9.png
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(3).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(7).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/30b06.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(3).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/styles.css
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/800(1).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f.txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f21a9.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(5).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(4).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(1).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/6636b.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(10).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(11).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/67b5b.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(8).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/275(3).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/0a315.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/ads-cch-20181026165210.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/widgetGlobalEvent(2)
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(2).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/getids
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/226ee.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/widget.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/gather_id(1)
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/0CA20181029124202ADs201810291242024F98d8q4aBxcs.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/gen_204.gif
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/275(2).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/6f4bb.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/widgetGlobalEvent(1)
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/4f412.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/tag.min.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/110.png
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(6).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/gpt.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/800.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/1ce06.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/1x1.a
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/widget.css
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(7).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/3b4c8.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/get(2)
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(9).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/49d3b.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/wonderpush-loader.min.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/2402-245398-48616-4.gif
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(8).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(2).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/0f245.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(5).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/guid.html
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(4).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/hudactive.html
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/201b8.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/140(6).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/20d4b.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/275(5).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/SVG-EFR.svg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/44ddc.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/V6zvOIoD.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/get(1)
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/fbevents.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/wamfactory_dpm.lequipe.min.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/275(4).jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/wonderpush.min.js
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/3c6f0.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/gen_204(1).gif
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(10).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/6uQTKQJz(1).html
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/fb0a7.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/2402-245398-48616-4(1).gif
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/gather_id
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/275.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(9).txt
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/SVG-EFR(1).svg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/get
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/125278988146629
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/wonderpush.min.html
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/6uQTKQJz.html
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/widgetGlobalEvent
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f3de7.jpg
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/275(1).jpg

# %% [markdown]
# Create a list of all the **`.txt` files** from the `data/` directory

# %%
txt_files = []
new_path = os.path.abspath("./data")
print(new_path)

for path, dirs, files in os.walk(new_path):
    for filename in files:
        if ".txt" in filename:
            txt_files.append(os.path.join(path, filename))

print(txt_files)
# Out:
# /home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data
# ['/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX09.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/mail.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX01.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX90.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX89.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX75.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX06.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/data.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX07.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX87.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX83.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX05.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX08.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX74.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/final.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX94.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/write.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/data_new.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/VOEUX79.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(7).txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(3).txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f.txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(4).txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(2).txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(6).txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(8).txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(5).txt', '/home/siegfried2021/Bureau/BeCode_AI/LGG-Thomas4-Mathieu/01-TheField/02-Python/02-PythonAdvanced/04-FileHandling/data/lequipe-du sport en continu._files/f(10).txt' ...

# %% [markdown]
# Open all the files of the list, and add their content into a new file `final.txt` that you will create in `data/`.

# %%
with open("./data/final.txt", "w", encoding="latin-1") as new_file:
    for filename in txt_files:
        with open(filename, "r", encoding="latin-1") as text_file:
            content = text_file.read()
            new_file.write(content)
            new_file.write("\n")
        
with open("./data/final.txt", "r", encoding="latin-1") as test:
    print(test.read())
# Out:
# tapia_upson@ecoin.me
# uddin_yocum@gaagle.hu
# bongardroger@napster.net
# victor@youhoo.gov
# ty.schwager@napster.io
# paultiernan@youhoo.xyz
# roger836@gaagle.tech
# pettigrew.victor@email.io
# steve.ingram@mail.bocode.me
# johnsen4863@gaagle.apple
# soloman-roger@ecoin.apple
# 34658710@mail.bocode.xyz
# cannon-joe@mail.bocode.io
# 284857146@mail.adlp.net
# 890280316@ecoin.me
# kalleg-joe@belgaximus.com
# weinstein.roger@imail.io
# alexschmitt@odul.org
# dan.uddin@ecoin.apple
# steve.stahl@hotmoille.me
# matthewfrick@hotmoille.com
# 237336989@email.io
# larry6016@youhoo.org
# otto5489@gaagle.tech
# bongard_ty@ecoin.xyz
# 169102677@gaagle.me
# upson.hal@gaagle.io
# hal@hotmoille.gov
# lepage-aaron@hotmoille.apple
# sonderling_mark@belgaximus.me
# 430581778@hotmoille.com
# walterkassing@napster.tech
# victorceledon@ecoin.xyz
# hesch-john@odul.io
# kassing@hotmoille.apple
# duffman6005@youhoo.hu
# frank.ventotla@belgaximus.io
# uddinotto@youhoo.org
# 703979481@ecoin.apple
# paul.nugent@ecoin.apple
# nugent@proton.org
# alex@odul.tech
# aaronsweeney@ecoin.apple
# knutson_celedon@hotmoille.xyz
# tydoran@belgaximus.org
# millerhal@hotmoille.org
# adamnuttle@youhoo.hu
# ashwoon8609@youhoo.tech
# victormiller@mail.bocode.org
# mcginnis_reardon@youhoo.org
# ramachandran.mark@proton.com
# monteshaffer@proton.tech
# monte@proton.gov
# pettigrew9750@proton.com
# yocum_dan@napster.xyz
# yocum-victor@imail.xyz
# darnell8483@email.xyz
# zeller-matthew@ecoin.apple
# pettigrewlarry@imail.tech
# yocum8146@mail.bocode.me
# ben5039@hotmoille.tech
# mcginnis.dan@gaagle.tech
# roger.vogal@email.xyz
# adamtisler@gaagle.xyz
# matthew3420@hotmoille.tech
# john8770@napster.hu
# hesch_zeller@email.apple
# christensen_ben@proton.com
# walter.soulis@email.com
# ben8671@proton.tech
# frankjagtap@napster.com
# peternuttle@napster.gov
# victor8847@ecoin.io
# ferry.paul@imail.org
# 690377034@gaagle.apple
# lepageroger@proton.gov
# john.zeaser@imail.gov
# valente-jack@gaagle.me
# 4709006@napster.tech
# deitz-monte@odul.gov
# fietzer-frank@hotmoille.tech
# kaskel5284@belgaximus.org
# davidson-monte@mail.bocode.xyz
# cataldi_ingram@mail.bocode.tech
# hanktiernan@youhoo.io
# ripka2474@hotmoille.tech
# cataldi_matthew@odul.me
# lewis_lulloff@mail.adlp.org
# matthewmccord@mail.bocode.me
# turco8476@mail.adlp.apple
# steve6967@odul.hu
# ortiz-larry@napster.org
# irwincarl@belgaximus.gov
# wakefieldjoe@ecoin.org
# nathansagar@email.apple
# hydinger_larry@odul.xyz
# frank.yates@proton.gov
# fred@mail.adlp.apple
# schuster5868@youhoo.tech
# rogerschwager@imail.tech
# 163622426@imail.com
# baxstercarl@proton.net
# yang-hal@mail.adlp.net
# lawless.fred@imail.tech
# paulkassing@mail.adlp.gov
# fredroot@odul.com
# hesch-ty@napster.tech
# napier3011@email.com
# napier_ortiz@mail.bocode.org
# tynapier@napster.org
# ty3947@ecoin.io
# ben@odul.com
# resnickmonte@mail.bocode.hu
# sawyer@imail.com
# kaskel-peter@youhoo.tech
# schwager9365@hotmoille.io
# aaronlewis@proton.gov
# nelson_jack@gaagle.apple
# upson1390@proton.apple
# 871781143@odul.org
# 269062053@youhoo.me
# victorreardon@proton.com
# soloman@gaagle.tech
# aaronsagar@ecoin.org
# alex@odul.hu
# van zandt2300@gaagle.xyz
# ike5340@email.apple
# 120987413@email.tech
# ziegler@hotmoille.hu
# van zandt@email.me
# tisler.monte@odul.gov
# van zandt8519@odul.me
# victorquinn@gaagle.io
# lulloffhal@mail.bocode.net
# aaronebner@youhoo.apple
# fred.moore@gaagle.net
# adam3605@gaagle.io
# thompson@mail.adlp.hu
# stevewagle@napster.com
# montedeitz@napster.hu
# vanderpoel-adam@proton.gov
# orwig_john@email.org
# roger@napster.apple
# edwarddeitz@gaagle.tech
# 273554425@proton.gov
# edward.darnell@proton.org
# marknapier@youhoo.com
# paul635@mail.adlp.xyz
# upson.peter@gaagle.me
# john.stahl@email.xyz
# duffman.aaron@proton.hu
# jenson@hotmoille.hu
# rogermcginnis@napster.tech
# soukup@belgaximus.gov
# soloman@odul.apple
# 877692701@napster.hu
# tandyaaron@ecoin.tech
# ingramthomas@youhoo.xyz
# aaron8129@belgaximus.apple
# vanderpoeljoe@mail.adlp.io
# fredmills@imail.net
# haljagtap@hotmoille.org
# larry.hancock@mail.bocode.xyz
# soloman_eastman@email.com
# montelewis@gaagle.org
# 631338425@mail.adlp.gov
# peter.mccord@gaagle.com
# hylan@mail.bocode.apple
# roger@proton.io
# paiser@youhoo.gov
# schickowski-steve@belgaximus.gov
# ty@imail.gov
# roberts@youhoo.gov
# 958642438@email.net
# boyd3853@belgaximus.net
# soloman_nathan@youhoo.gov
# 92101346@proton.tech
# chambers.mark@napster.com
# nuttleedward@gaagle.apple
# adamrice@ecoin.net
# fred937@odul.com
# ben@belgaximus.hu
# lepagemark@mail.adlp.xyz
# dan@gaagle.gov
# walterturco@imail.tech
# ebner_fred@mail.bocode.net
# danwagner@mail.bocode.gov
# jones206@mail.bocode.com
# steve.root@mail.adlp.net
# roger.fletcher@belgaximus.xyz
# casal.david@mail.bocode.tech
# adamziegler@youhoo.org
# 275056493@youhoo.xyz
# peterlewis@belgaximus.gov
# jack@imail.net
# george3788@gaagle.com
# seversonpaul@mail.adlp.xyz
# zeller.roger@youhoo.me
# ottoschmitt@odul.org
# fietzer_cast@mail.bocode.tech
# tiernan.jack@ecoin.apple
# schutz_knutson@gaagle.gov
# matthew2395@mail.adlp.net
# hal.severson@youhoo.hu
# reyes-paul@imail.gov
# mccord_ferry@odul.gov
# uddin2208@youhoo.me
# moody1342@mail.adlp.com
# roger6727@imail.me
# schlicht670@hotmoille.net
# steve@odul.xyz
# sawyer@napster.apple
# soulis2863@belgaximus.hu
# yates.steve@mail.adlp.io
# sonderling4257@email.org
# upson_paul@gaagle.org
# timtrebil@belgaximus.tech
# 104036307@ecoin.me
# frankupson@imail.apple
# fietzeralex@youhoo.hu
# solomanjohn@youhoo.apple
# peter6564@email.hu
# johnsen2199@gaagle.tech
# uflan-frank@belgaximus.apple
# lepage_edward@ecoin.net
# dugelman8872@odul.me
# carlvanderpoel@mail.adlp.apple
# vanderpoel_hydinger@odul.xyz
# ripka2789@email.io
# chambers.aaron@mail.adlp.com
# nathan2454@mail.adlp.xyz
# larry1596@imail.tech
# moorety@napster.io
# roger.fietzer@belgaximus.apple
# soulispeter@imail.io
# victorschmitt@mail.bocode.org
# ty3503@imail.apple
# lepage_ostrander@hotmoille.io
# vanderpoel_dan@gaagle.net
# darnellty@gaagle.org
# kalleg_david@belgaximus.gov
# steve@odul.apple
# lulloff.matthew@proton.hu
# chamberspaul@odul.com
# anderson845@mail.bocode.com
# quizoz_upson@mail.adlp.tech
# bencasal@odul.io
# vader_john@napster.org
# mark.lepage@mail.adlp.apple
# lepage6698@email.hu
# zeller_ziegler@ecoin.tech
# walterschwager@email.io
# christensenty@napster.xyz
# severson_woo@proton.org
# vailjoe@imail.io
# tiernan-frank@napster.org
# dewalt_adam@proton.net
# rogertrebil@mail.bocode.gov
# ziegler8928@imail.net
# duffman-ben@hotmoille.hu
# wakefield_edward@youhoo.tech
# dugelman_van zandt@gaagle.net
# nugent1331@proton.xyz
# frick-otto@hotmoille.hu
# celedon_severson@odul.me
# ty.tiernan@odul.gov
# schmitt@imail.org
# aaronwagle@email.tech
# woo@hotmoille.io
# tim9542@hotmoille.tech
# john5694@email.me
# sagar_nathan@belgaximus.xyz
# larry.dinkins@proton.com
# severson.steve@imail.hu
# fredturco@odul.net
# victoringram@mail.adlp.apple
# edward@youhoo.com
# tisler-matthew@imail.me
# reyes.roger@ecoin.tech
# reamer_tim@hotmoille.org
# schlicht-carl@ecoin.net
# steve3131@email.tech
# wagner9136@gaagle.apple
# davis_bowers@belgaximus.me
# edward9079@napster.net
# 283141330@gaagle.hu
# tyduffman@hotmoille.hu
# walterhydinger@ecoin.io
# ben9635@odul.apple
# vanderpoel.mark@odul.tech
# delorenzo.jack@napster.xyz
# chapman-roger@mail.adlp.com
# nathan.woo@proton.org
# victorvader@belgaximus.tech
# bateman1522@mail.bocode.net
# ben.irwin@email.net
# fredhaworth@mail.bocode.io
# eastman_larry@napster.apple
# sweeney_alex@hotmoille.hu
# hydinger_otto@email.apple
# peter2600@belgaximus.apple
# eastman_adam@imail.xyz
# thomas@gaagle.com
# hal@napster.gov
# paulresnick@gaagle.me
# 682804922@ecoin.hu
# ziegler-alex@odul.me
# maki-frank@mail.adlp.hu
# myerspeter@youhoo.me
# fred67@youhoo.net
# edwardhoffman@napster.apple
# nuttle-monte@email.gov
# thompson_orwig@napster.com
# ike.stahl@hotmoille.apple
# markhoffman@imail.org
# 669214282@imail.com
# hank@proton.com
# thomas@email.xyz
# alexcataldi@napster.org
# tim@mail.bocode.apple
# hankulrich@belgaximus.hu
# otto.reamer@mail.adlp.net
# rogerchambers@mail.bocode.io
# alexdavidson@mail.adlp.net
# peter.moody@proton.io
# ben.weinstein@odul.apple
# davidson_jack@youhoo.xyz
# jacksellon@napster.io
# cataldiedward@hotmoille.io
# sellon.jack@ecoin.net
# 748522766@gaagle.xyz
# victorsweeney@odul.tech
# nelson-matthew@belgaximus.me
# johnmoody@imail.xyz
# peter.sandstrom@napster.xyz
# montelulloff@email.io
# andersonhal@odul.apple
# napier_hank@belgaximus.hu
# moodygeorge@proton.net
# peter4809@email.net
# marknapier@proton.io
# darnell_roger@hotmoille.net
# george@belgaximus.gov
# tim.weinstein@odul.io
# pak_roger@proton.com
# georgecasal@hotmoille.tech
# trusela-jack@email.net
# thomasvan zandt@email.tech
# fred.martin@youhoo.apple
# alex@proton.apple
# dan.ventotla@proton.gov
# dewalt_joe@email.com
# celedon_hesch@youhoo.net
# ty8684@odul.apple
# nuttle_yang@youhoo.hu
# hal.rice@napster.com
# 821663824@odul.apple
# mccord.fred@proton.apple
# orwig@ecoin.xyz
# 857071926@mail.bocode.net
# turcolarry@gaagle.hu
# mcginnis_aaron@email.com
# johnpettigrew@proton.hu
# root-edward@gaagle.hu
# hal.yocum@email.apple
# monteschuster@belgaximus.gov
# fietzer_mark@gaagle.tech
# 271794997@imail.gov
# hancock@imail.tech
# wagle_doran@hotmoille.hu
# 558791202@napster.io
# woo-aaron@ecoin.com
# quinn1097@imail.org
# sawyer@proton.hu
# trebil5339@mail.adlp.hu
# norquist-mark@email.apple
# ory7664@belgaximus.net
# olsonjohn@belgaximus.tech
# orwigfrank@mail.adlp.xyz
# alexfrick@mail.adlp.apple
# knutson_matthew@odul.tech
# aikin7996@belgaximus.tech
# dewalt674@napster.io
# ventotla_haworth@imail.tech
# ike@ecoin.apple
# yates.hal@odul.io
# dan9881@mail.adlp.hu
# resnick_john@napster.xyz
# roger.deitz@gaagle.org
# pak.matthew@gaagle.gov
# edward@odul.io
# markmoore@email.tech
# schickowski.roger@hotmoille.net
# larrysandstrom@odul.org
# nathan@napster.gov
# fredolson@mail.adlp.apple
# nathan.rogers@odul.gov
# nelson-peter@proton.com
# adameastman@email.me
# solberg@mail.adlp.me
# carl.mcginnis@email.apple
# benwoo@mail.adlp.tech
# trussel_moore@mail.adlp.hu
# vader_thompson@mail.adlp.gov
# davidashwoon@belgaximus.tech
# sawyer.steve@imail.me
# rogerbateman@mail.adlp.tech
# dinkins_weinstein@mail.bocode.org
# resnick-edward@mail.bocode.tech
# rogercannon@youhoo.io
# ebner_walter@mail.adlp.xyz
# aaron@hotmoille.gov
# halduffman@mail.bocode.hu
# celedon_ostrander@email.gov
# rogerhoffman@email.apple
# victor2949@hotmoille.org
# matthew.schwager@imail.com
# dan9862@ecoin.com
# lawicki-carl@gaagle.net
# tislertim@mail.bocode.com
# victor3334@belgaximus.apple
# alex@mail.adlp.tech
# casal@imail.com
# rogerlawless@mail.bocode.hu
# jackhoffman@imail.gov
# adam4353@odul.gov
# ben.lewis@proton.gov
# tiernan9526@youhoo.io
# sweeney3123@youhoo.gov
# delorenzo.thomas@email.org
# wagle@napster.io
# 527881805@ecoin.apple
# 872834724@mail.bocode.tech
# linde443@gaagle.xyz
# hydinger2431@email.me
# ory-paul@odul.io
# ferro@imail.xyz
# paul.tandy@mail.bocode.hu
# leisinger7925@gaagle.hu
# otto@email.org
# sawyerdan@youhoo.tech
# ulrich@belgaximus.apple
# dewaltjohn@ecoin.xyz
# daviduddin@odul.hu
# schuster4665@hotmoille.apple
# walter@hotmoille.io
# aikin@proton.tech
# haltisler@gaagle.io
# roger.nuttle@hotmoille.hu
# frankmccord@odul.gov
# 790068404@imail.net
# fletcher.peter@proton.apple
# paul@proton.gov
# nugent2277@mail.adlp.tech
# johndugelman@napster.xyz
# markwagle@napster.tech
# ferry9419@mail.bocode.xyz
# joe@hotmoille.org
# sonderling_dinkins@email.io
# matthewtrebil@mail.bocode.me
# rogerchapman@proton.net
# vanderpoel.roger@imail.com
# joe2475@imail.tech
# paiser_moody@proton.io
# paiser@ecoin.me
# peter.ventotla@napster.me
# tiernan-ike@email.com
# 524167342@odul.com
# hal.nugent@gaagle.me
# vanderpoel-matthew@mail.adlp.xyz
# petersawyer@gaagle.net
# edward1595@hotmoille.gov
# thomasroot@ecoin.net
# 720054838@hotmoille.net
# 835555730@belgaximus.io
# mccord969@mail.adlp.com
# lawicki-ben@youhoo.gov
# edwardjenson@hotmoille.io
# darnell_ty@belgaximus.me
# hank2676@imail.gov
# victorturco@email.apple
# dugan@email.hu
# fred6946@hotmoille.me
# ferro@ecoin.hu
# ostrander_roger@mail.bocode.apple
# stevewagle@mail.bocode.org
# carl.keller@mail.bocode.apple
# hal7714@youhoo.me
# 921295508@youhoo.org
# hank944@ecoin.io
# turco_david@proton.org
# baxster@odul.io
# schutz_tiernan@imail.org
# boyd_eastman@imail.net
# tislermonte@hotmoille.gov
# ferrynathan@odul.tech
# aikin_johnsen@hotmoille.hu
# carlschuster@hotmoille.com
# adamferro@email.xyz
# haworth_ostrander@proton.me
# peterostrander@odul.apple
# matthew.schlicht@odul.apple
# zeller_ty@odul.xyz
# fred542@proton.com
# chapman_roger@hotmoille.io
# shaffer@gaagle.xyz
# napier_tim@email.org
# resnick_soloman@youhoo.io
# hydinger.victor@ecoin.io
# reardonnathan@imail.com
# larry5230@mail.adlp.com
# irwinfrank@email.org
# trebilroger@mail.adlp.xyz
# 778805808@gaagle.net
# benduffman@hotmoille.com
# stahl_peter@hotmoille.apple
# zeaser_lawicki@napster.xyz
# tisler@proton.io
# john@youhoo.tech
# daviddavidson@ecoin.org
# joeschmitt@imail.com
# jones3480@odul.gov
# hal.davidson@belgaximus.apple
# dan.soloman@email.xyz
# trusela-joe@email.net
# pak_aaron@imail.io
# pettigrew_walter@youhoo.io
# solberg_peter@email.com
# ory.ike@mail.bocode.apple
# ottoreamer@belgaximus.xyz
# ebner2247@odul.org
# rogerlawicki@odul.com
# adam3493@youhoo.io
# 105225941@mail.adlp.com
# edwardtiernan@proton.com
# hal@imail.hu
# tyquinn@hotmoille.net
# thomashancock@gaagle.hu
# wagle-carl@email.tech
# quinn_david@odul.org
# 19623159@mail.bocode.com
# ebner.thomas@ecoin.com
# cast3500@proton.io
# edward@ecoin.hu
# schwager4149@mail.bocode.tech
# hal.vogal@ecoin.io
# fred6097@email.xyz
# uddin_celedon@youhoo.xyz
# 328027994@odul.apple
# doran.victor@belgaximus.xyz
# petersonderling@ecoin.gov
# alexlawless@hotmoille.com
# fletcher6080@proton.org
# david9675@belgaximus.tech
# lewis-thomas@imail.tech
# hal@youhoo.org
# shaffer_adam@imail.me
# orysteve@gaagle.apple
# zellerty@email.org
# resnick_ty@hotmoille.gov
# turcolarry@napster.gov
# roger7870@imail.xyz
# solberg.monte@gaagle.tech
# ikeolson@imail.xyz
# tim.vogal@napster.me
# davidson_joe@imail.apple
# 113992553@proton.gov
# weiss_keller@hotmoille.io
# roberts5261@email.hu
# dugan.larry@mail.bocode.com
# thompsonhank@email.tech
# trussel.adam@youhoo.gov
# schwager@odul.tech
# paul@odul.net
# jackferro@youhoo.xyz
# ingram_schutz@hotmoille.apple
# wagner.larry@hotmoille.xyz
# tyshaffer@napster.com
# tapia287@ecoin.net
# fred4639@email.xyz
# steveingram@gaagle.tech
# alex@gaagle.me
# moody_alex@belgaximus.me
# peterrice@mail.adlp.net
# davidyates@odul.gov
# sellon_mark@ecoin.org
# duganjack@napster.tech
# george7677@hotmoille.io
# 947932051@gaagle.me
# kassingmonte@imail.com
# reyesgeorge@mail.bocode.hu
# edward.orwig@gaagle.org
# lawless_steve@imail.me
# soulis_matthew@proton.tech
# vail7262@hotmoille.hu
# christensen_adam@imail.org
# chamberspaul@gaagle.com
# carlripka@proton.org
# thompson@imail.gov
# shaffernathan@hotmoille.io
# schlicht4183@mail.adlp.com
# haworth1948@gaagle.gov
# bongard_wagle@mail.adlp.io
# nathan@napster.com
# george.davidson@hotmoille.net
# john6870@napster.com
# ashwoon-george@ecoin.xyz
# baxster_hal@napster.io
# monte.ebner@gaagle.io
# paiser_paiser@imail.org
# danyocum@youhoo.io
# heschedward@ecoin.org
# george.schutz@gaagle.tech
# hancock_walter@youhoo.xyz
# doran@email.io
# hylan.george@mail.adlp.org
# otto@mail.adlp.io
# leisinger_joe@imail.hu
# thomas4571@gaagle.org
# ramachandran2353@napster.hu
# davidson_schuster@hotmoille.net
# schlicht-david@mail.adlp.hu
# nathan6101@email.gov
# mills-larry@belgaximus.me
# matthew@imail.tech
# rogers4495@mail.bocode.org
# joe@mail.bocode.xyz
# 290720979@mail.bocode.io
# sellon_cast@ecoin.hu
# ziegler.victor@mail.adlp.xyz
# 841777083@mail.bocode.hu
# root-david@ecoin.hu
# matthew@youhoo.net
# wagle_ferry@napster.hu
# peter7101@mail.adlp.apple
# walterpaiser@youhoo.net
# darnell@napster.gov
# hank2051@ecoin.xyz
# thomas.cataldi@ecoin.com
# thompson_roger@odul.io
# roger4607@napster.com
# keller_walter@odul.io
# matthew.uflan@imail.gov
# joe.kaskel@napster.tech
# cataldidavid@belgaximus.gov
# roger.upson@odul.me
# thomaspaiser@odul.org
# victor@napster.net
# orwig.larry@napster.apple
# ferro7108@gaagle.apple
# johnsen.matthew@napster.hu
# ebner.fred@hotmoille.hu
# victor9493@hotmoille.hu
# peter6703@ecoin.gov
# sweeney.jack@mail.bocode.hu
# nathan.miller@mail.adlp.gov
# delorenzothomas@youhoo.net
# miller6509@proton.xyz
# nelsongeorge@mail.bocode.gov
# hancock5965@imail.hu
# illingsworthaaron@napster.apple
# ostrander@belgaximus.xyz
# monte6005@email.net
# 56345021@gaagle.io
# fietzer@ecoin.tech
# tyreardon@odul.xyz
# sweeney.matthew@mail.adlp.apple
# zeaserpeter@youhoo.hu
# montehydinger@hotmoille.com
# hank5419@proton.hu
# cannon965@youhoo.gov
# joe@youhoo.hu
# shaffer.paul@gaagle.xyz
# lawless_thomas@napster.me
# chambers@gaagle.io
# nathanferro@proton.io
# lewis-thomas@youhoo.gov
# mark9494@belgaximus.org
# anderson2753@mail.bocode.me
# dinkins_carl@email.xyz
# 379512415@napster.org
# paulmyers@ecoin.io
# sawyer@imail.me
# fred@mail.adlp.hu
# georgevalente@odul.apple
# nelson-walter@hotmoille.io
# dan@youhoo.apple
# vail.monte@odul.com
# upson_deitz@imail.tech
# victorwoo@mail.bocode.apple
# fred.soulis@gaagle.gov
# vail_david@youhoo.me
# delorenzo.frank@odul.org
# victor@youhoo.io
# 9505661@gaagle.hu
# jackbateman@odul.com
# dan.vogal@mail.bocode.apple
# kassing-john@proton.me
# van zandtwalter@ecoin.xyz
# 984521262@belgaximus.tech
# chapman_moore@hotmoille.io
# moore4976@mail.bocode.gov
# nathan.ortiz@youhoo.net
# 997040446@youhoo.net
# adam@odul.tech
# vader_kalleg@napster.apple
# nathan@youhoo.hu
# timdugelman@email.gov
# john3292@odul.gov
# ripka@ecoin.io
# ostrander6580@youhoo.hu
# ebner-otto@imail.hu
# cannon-steve@proton.gov
# benmartin@hotmoille.me
# hankmills@napster.gov
# ricemark@ecoin.apple
# mcginnis_steve@odul.xyz
# davidschickowski@mail.bocode.tech
# chambers_alex@napster.me
# joe3218@napster.tech
# davidramachandran@odul.com
# ebner@gaagle.gov
# shaffer-aaron@mail.adlp.gov
# jenson_weinstein@hotmoille.gov
# leisinger.alex@odul.xyz
# vogal@ecoin.apple
# hank.schutz@mail.bocode.org
# sandstrom.walter@youhoo.hu
# aaronchristensen@odul.gov
# 204190257@hotmoille.org
# joemyers@mail.adlp.gov
# jacktrebil@proton.me
# hanktiernan@odul.hu
# robertsike@gaagle.apple
# edward.linde@mail.bocode.org
# celedon.larry@proton.gov
# ferry-carl@hotmoille.org
# valente_orwig@ecoin.net
# matthewpaiser@imail.gov
# schmitt.john@hotmoille.io
# ben.rice@hotmoille.com
# jack@email.io
# cannon2402@youhoo.xyz
# markdewalt@hotmoille.hu
# peterweinstein@proton.me
# alexdugelman@youhoo.com
# severson.ike@proton.xyz
# fletcher.otto@mail.adlp.net
# dan7229@napster.io
# halpaiser@youhoo.tech
# reamer_jack@hotmoille.io
# markduffman@mail.adlp.gov
# alex60@proton.tech
# 911067980@mail.bocode.gov
# 422879919@imail.org
# hal3545@gaagle.xyz
# johndeitz@proton.org
# ferry.steve@mail.adlp.me
# lewis.hank@ecoin.tech
# wakefield2753@mail.adlp.me
# thomas.kaskel@ecoin.apple
# 236837196@mail.adlp.hu
# eastman-thomas@mail.bocode.hu
# zeller_rice@odul.org
# wakefield2542@email.org
# wagner7015@imail.xyz
# fredleisinger@imail.tech
# victor.leisinger@imail.tech
# peter.bongard@belgaximus.apple
# valente_joe@ecoin.gov
# alex.lepage@odul.me
# ulrich_roger@mail.adlp.io
# roger.christensen@napster.org
# soulis-ben@mail.bocode.tech
# 44618225@proton.gov
# lulloff.edward@proton.net
# reamer@belgaximus.apple
# frankdugan@napster.org
# reyesben@belgaximus.me
# mark@napster.org
# rootmark@email.io
# adam.linde@youhoo.apple
# schiebel_matthew@hotmoille.tech
# kalleg_bateman@gaagle.hu
# steve.schiebel@proton.hu
# 603040843@proton.com
# tim1279@napster.hu
# schusterfrank@gaagle.io
# timjurgenson@youhoo.me
# vanderpoeldan@imail.org
# mcginnis5939@odul.tech
# tisler.ben@napster.hu
# victorresnick@mail.adlp.org
# 354920004@odul.com
# ...
#
# document.write('\x3cdiv id\x3d\x22ad_unit\x22\x3e\x3cscript\x3e(function() {(function(){var h\x3dthis,k\x3dfunction(a){var b\x3dtypeof a;if(\x22object\x22\x3d\x3db)if(a){if(a instanceof Array)return\x22array\x22;if(a instanceof Object)return b;var c\x3dObject.prototype.toString.call(a);if(\x22[object Window]\x22\x3d\x3dc)return\x22object\x22;if(\x22[object Array]\x22\x3d\x3dc||\x22number\x22\x3d\x3dtypeof a.length\x26\x26\x22undefined\x22!\x3dtypeof a.splice\x26\x26\x22undefined\x22!\x3dtypeof a.propertyIsEnumerable\x26\x26!a.propertyIsEnumerable(\x22splice\x22))return\x22array\x22;if(\x22[object Function]\x22\x3d\x3dc||\x22undefined\x22!\x3dtypeof a.call\x26\x26\x22undefined\x22!\x3dtypeof a.propertyIsEnumerable\x26\x26!a.propertyIsEnumerable(\x22call\x22))return\x22function\x22}else return\x22null\x22;else if(\x22function\x22\x3d\x3db\x26\x26\x22undefined\x22\x3d\x3dtypeof a.call)return\x22object\x22;return b},l\x3dfunction(a,b){var c\x3dArray.prototype.slice.call(arguments,1);return function(){var b\x3dc.slice();b.push.apply(b,arguments);return a.apply(this,b)}};var m\x3dfunction(a,b){for(var c in a)b.call(void 0,a[c],c,a)};var p\x3dfunction(a){a\x3da?a.toLowerCase():\x22\x22;switch(a){case \x22normal\x22:return\x22normal\x22;case \x22lightbox\x22:return\x22lightbox\x22;case \x22push_down\x22:return\x22push_down\x22}return null};var q\x3d{i:\x22ad_container_id\x22,A:\x22hideObjects\x22,X:\x22mtfTop\x22,W:\x22mtfLeft\x22,ca:\x22zindex\x22,m:\x22mtfDuration\x22,aa:\x22wmode\x22,Z:\x22preferFlash\x22,s:\x22as_kw\x22,u:\x22as_lat\x22,v:\x22as_lng\x22,B:\x22mtfIFPath\x22,o:\x22expansionMode\x22,U:\x22top_container\x22,T:\x22mtfTopFloat\x22,S:\x22mtfTopDuration\x22,V:\x22mtfTopWmode\x22,P:\x22right_container\x22,O:\x22mtfRightFloat\x22,N:\x22mtfRightDuration\x22,R:\x22mtfRightWmode\x22,H:\x22bottom_container\x22,G:\x22mtfBottomFloat\x22,F:\x22mtfBottomDuration\x22,I:\x22mtfBottomWmode\x22,L:\x22left_container\x22,K:\x22mtfLeftFloat\x22,J:\x22mtfLeftDuration\x22,M:\x22mtfLeftWmode\x22,$:\x22mtfRenderFloatInplace\x22,ba:\x22tryToWriteHtmlInline\x22,j:\x22debugjs\x22,C:\x22dcapp\x22,g:\x22breakoutiframe\x22,D:\x22inMobileAdSdk\x22},t\x3dfunction(a){m(a,function(b,c){if(c.toLowerCase()in r){var e\x3dr[c.toLowerCase()];c in a\x26\x26delete a[c];a[e]\x3db}})},r\x3dfunction(){var a\x3d{};m(q,function(b){a[b.toLowerCase()]\x3db});return a}();var v\x3dfunction(a){this.a\x3da;a:{for(c in a.displayConfigParameters){b:if(a\x3du,\x22string\x22\x3d\x3dtypeof a)a\x3d\x22string\x22\x3d\x3dtypeof c\x26\x261\x3d\x3dc.length?a.indexOf(c,0):-1;else{for(var b\x3d0;b\x3ca.length;b++)if(b in a\x26\x26a[b]\x3d\x3d\x3dc){a\x3db;break b}a\x3d-1}if(!(0\x3c\x3da)){var c\x3d!0;break a}}c\x3d!1}this.f\x3dc},u\x3d[\x22ad_container_id\x22],w\x3dfunction(a){return a.f?a.a.displayConfigParameters:a.a.creativeParameters},x\x3dfunction(a,b){for(var c\x3d0;c\x3ca.a.primaryFiles.length;++c)if(a.a.primaryFiles[c].type\x3d\x3db)return!0;return!1};var y\x3d{pattern:/rendering_lib_((?:[0-9_]+)|(?:latest))\\.js$/,c:\x22rendering_lib_db_$1.js\x22},z\x3d{pattern:/\\/[a-z_0-9]+_rendering_lib/,c:\x22/iframe_buster\x22},A\x3d{pattern:/(.*\\/)(.*_)rendering_lib_((?:[0-9_]+)|(?:latest))\\.js$/,c:\x22$1inapp_html_inpage_rendering_lib_$3.js\x22},B\x3d{pattern:/\\/[0-9]+\\/[a-z_0-9]+rendering_lib.+$/,c:\x22/ads/studio/cached_libs/modernizr_2.8.3_ec185bb44fe5e6bf7455d6e8ef37ed0e_no-classes.js\x22},C\x3dfunction(){var a\x3d[];a.push(\x22e\x3d101\x22);a.push(\x22renderingType\x3d2\x22);a.push(\x22leftOffset\x3d0\x22);a.push(\x22topOffset\x3d0\x22);a.push(\x22t\x3d1\x22);return\x22?\x22+a.join(\x22\x26\x22)},G\x3dfunction(a){var b\x3dw(a),c\x3da.a,e\x3dc.renderingLibraryData,f\x3de.renderingLibrary,d\x3de.version;if(!/express|image_gallery|dfa7banner|inapp/.test(f)\x26\x26(\x22latest\x22\x3d\x3dd||0\x3c\x3dD(d,\x22200_74\x22))){if(d\x3d!x(a,\x22FLASH\x22)){a:{for(d\x3d0;d\x3ca.a.primaryFiles.length;++d){var g\x3da.a.primaryFiles[d].expandingDisplayProperties;if(g\x26\x26\x22lightbox\x2 ...
# processGoogleToken({"newToken":"AOhZihu7k_SVeEp4ihBhbhnZKQrVoj7Q1_Vec90e07xNLlJF2jH7yGSwBw","validLifetimeSecs":300,"freshLifetimeSecs":300,"1p_jar":"2018-10-29-14","pucrd":"CgwIABAAGAMgACgAOAF4Aw"});
# (function(){function f(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}}function n(a){var b="undefined"!=typeof Symbol&&Symbol.iterator&&a[Symbol.iterator];return b?b.call(a):{next:f(a)}}var p=this;function q(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var c=Object.prototype.toString.call(a);if("[object Window]"==c)return"object";if("[object Array]"==c||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";if("[object Function]"==c||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";else if("function"==b&&"undefined"==typeof a.call)return"object";return b}function r(a,b,c){return a.call.apply(a.bind,arguments)}function t(a,b,c){if(!a)throw Error();if(2<arguments.length){var d=Array.prototype.slice.call(arguments,2);return function(){var c=Array.prototype.slice.call(arguments);Array.prototype.unshift.apply(c,d);return a.apply(b,c)}}return function(){return a.apply(b,arguments)}}function v(a,b,c){Function.prototype.bind&&-1!=Function.prototype.bind.toString().indexOf("native code")?v=r:v=t;return v.apply(null,arguments)}var x=Date.now||function(){return+new Date};function y(a,b){function c(){}c.prototype=b.prototype;a.B=b.prototype;a.prototype=new c;a.prototype.constructor=a;a.C=function(a,c,G){for(var d=Array(arguments.length-2),e=2;e<arguments.length;e++)d[e-2]=arguments[e];return b.prototype[c].apply(a,d)}};var z=Array.prototype.forEach?function(a,b){Array.prototype.forEach.call(a,b,void 0)}:function(a,b){for(var c=a.length,d="string"==typeof a?a.split(""):a,e=0;e<c;e++)e in d&&b.call(void 0,d[e],e,a)};function A(){}var B="function"==typeof Uint8Array;function C(a,b,c){a.b=null;b||(b=[]);a.l=void 0;a.f=-1;a.a=b;a:{if(b=a.a.length){--b;var d=a.a[b];if(!(null===d||"object"!=typeof d||"array"==q(d)||B&&d instanceof Uint8Array)){a.g=b-a.f;a.c=d;break a}}a.g=Number.MAX_VALUE}a.i={};if(c)for(b=0;b<c.length;b++)if(d=c[b],d<a.g)d+=a.f,a.a[d]=a.a[d]||D;else{var e=a.g+a.f;a.a[e]||(a.c=a.a[e]={});a.c[d]=a.c[d]||D}}var D=[];function E(a,b){if(b<a.g){b+=a.f;var c=a.a[b];return c===D?a.a[b]=[]:c}if(a.c)return c=a.c[b],c===D?a.c[b]=[]:c}function F(a,b,c){a=E(a,b);return null==a?c:a}function I(a){var b=J;a.b||(a.b={});if(!a.b[1]){var c=E(a,1);c&&(a.b[1]=new b(c))}return a.b[1]}function K(a){var b=L;a.b||(a.b={});if(!a.b[1]){if(1<a.g){var c=1+a.f;var d=a.a[c];c=d===D?a.a[c]=[]:d}else d=a.c[1],c=d===D?a.c[1]=[]:d;d=[];for(var e=0;e<c.length;e++)d[e]=new b(c[e]);a.b[1]=d}b=a.b[1];b==D&&(b=a.b[1]=[]);return b}A.prototype.toString=function(){return this.a.toString()};function J(a){C(this,a,aa)}y(J,A);function L(a){C(this,a,null)}y(L,A);function M(a){C(this,a,null)}y(M,A);var aa=[1];var N=document,O=window;var ba={capture:!0},ca=function(a){var b=!1,c;return function(){b||(c=a(),b=!0);return c}}(function(){var a=!1;try{var b=Object.defineProperty({},"passive",{get:function(){a=!0}});p.addEventListener("test",null,b)}catch(c){}return a});function da(a){return a?a.passive&&ca()?a:a.capture||!1:!1}function P(a,b,c,d){a.addEventListener&&a.addEventListener(b,c,da(d))};function ea(a,b){for(var c in a)Object.prototype.hasOwnProperty.call(a,c)&&b.call(void 0,a[c],c,a)}function Q(a,b){a&&ea(b,function(b,d){a.style[d]=b})}function fa(a){for(var b=N.body,c=document.createDocumentFragment(),d=a.length,e=0;e<d;++e)c.appendChild(a[e]);b.appendChild(c)};function R(){this.b=this.b;this.c=this.c}R.prototype.b=!1;function ha(a){a.b||(a.b=!0,a.f())}R.prototype.f=function(){if(this.c)for(;this.c.length;)this.c.shift()()};function T(a,b,c){R.call(this);this.g=a;this.u=b||0;this.i=c;this.l=v(this.s,this)}y(T,R);T.prototype.a=0;T.prototype.f=function(){T.B.f.call(this);this.stop();delete this.g;delete this.i};T.prototype.start=function(a){this.stop();var b=this.l;a=void 0!==a?a:this.u;if("functio ...
#
# (function() {(function() {(function(){var h=this;function k(a,d){a=a.split(".");var b=h;a[0]in b||"undefined"==typeof b.execScript||b.execScript("var "+a[0]);for(var c;a.length&&(c=a.shift());)a.length||void 0===d?b[c]&&b[c]!==Object.prototype[c]?b=b[c]:b=b[c]={}:b[c]=d}var l=/^[\w+/_-]+[=]{0,2}$/,m=null;function n(a){var d=typeof a;if("object"==d)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return d;var b=Object.prototype.toString.call(a);if("[object Window]"==b)return"object";if("[object Array]"==b||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";if("[object Function]"==b||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";else if("function"==d&&"undefined"==typeof a.call)return"object";return d}function p(a){var d=n(a);return"array"==d||"object"==d&&"number"==typeof a.length}function q(a){var d=typeof a;return"object"==d&&null!=a||"function"==d};var r=Array.prototype.forEach?function(a,d){Array.prototype.forEach.call(a,d,void 0)}:function(a,d){for(var b=a.length,c="string"==typeof a?a.split(""):a,g=0;g<b;g++)g in c&&d.call(void 0,c[g],g,a)};function t(a){var d=a.length;if(0<d){for(var b=Array(d),c=0;c<d;c++)b[c]=a[c];return b}return[]};function u(a){if(!v.test(a))return a;-1!=a.indexOf("&")&&(a=a.replace(x,"&amp;"));-1!=a.indexOf("<")&&(a=a.replace(y,"&lt;"));-1!=a.indexOf(">")&&(a=a.replace(z,"&gt;"));-1!=a.indexOf('"')&&(a=a.replace(A,"&quot;"));-1!=a.indexOf("'")&&(a=a.replace(B,"&#39;"));-1!=a.indexOf("\x00")&&(a=a.replace(C,"&#0;"));return a}var x=/&/g,y=/</g,z=/>/g,A=/"/g,B=/'/g,C=/\x00/g,v=/[\x00&<>"']/;var D;a:{var E=h.navigator;if(E){var F=E.userAgent;if(F){D=F;break a}}D=""};function G(a,d){for(var b in a)d.call(void 0,a[b],b,a)}var H="constructor hasOwnProperty isPrototypeOf propertyIsEnumerable toLocaleString toString valueOf".split(" ");function I(a,d){for(var b,c,g=1;g<arguments.length;g++){c=arguments[g];for(b in c)a[b]=c[b];for(var e=0;e<H.length;e++)b=H[e],Object.prototype.hasOwnProperty.call(c,b)&&(a[b]=c[b])}};var J=-1!=D.indexOf("Opera"),K=-1!=D.indexOf("Trident")||-1!=D.indexOf("MSIE"),L=-1!=D.indexOf("Edge"),M=-1!=D.indexOf("Gecko")&&!(-1!=D.toLowerCase().indexOf("webkit")&&-1==D.indexOf("Edge"))&&!(-1!=D.indexOf("Trident")||-1!=D.indexOf("MSIE"))&&-1==D.indexOf("Edge"),N=-1!=D.toLowerCase().indexOf("webkit")&&-1==D.indexOf("Edge");function O(){var a=h.document;return a?a.documentMode:void 0}var P;a:{var Q="",R=function(){var a=D;if(M)return/rv:([^\);]+)(\)|;)/.exec(a);if(L)return/Edge\/([\d\.]+)/.exec(a);if(K)return/\b(?:MSIE|rv)[: ]([^\);]+)(\)|;)/.exec(a);if(N)return/WebKit\/(\S+)/.exec(a);if(J)return/(?:Version)[ \/]?(\S+)/.exec(a)}();R&&(Q=R?R[1]:"");if(K){var S=O();if(null!=S&&S>parseFloat(Q)){P=String(S);break a}}P=Q}var T=P,U;var V=h.document;U=V&&K?O()||("CSS1Compat"==V.compatMode?parseInt(T,10):5):void 0;var W;(W=!K)||(W=9<=Number(U));var aa=W;function X(){this.a="";this.b=Y}X.prototype.c=!0;var Y={};function ba(a,d){G(d,function(b,c){b&&"object"==typeof b&&b.c&&(b=b.a);"style"==c?a.style.cssText=b:"class"==c?a.className=b:"for"==c?a.htmlFor=b:Z.hasOwnProperty(c)?a.setAttribute(Z[c],b):0==c.lastIndexOf("aria-",0)||0==c.lastIndexOf("data-",0)?a.setAttribute(c,b):a[c]=b})}var Z={cellpadding:"cellPadding",cellspacing:"cellSpacing",colspan:"colSpan",frameborder:"frameBorder",height:"height",maxlength:"maxLength",nonce:"nonce",role:"role",rowspan:"rowSpan",type:"type",usemap:"useMap",valign:"vAlign",width:"width"};function ca(a,d,b){var c=arguments,g=document,e=String(c[0]),f=c[1];if(!aa&&f&&(f.name||f.type)){e=["<",e];f.name&&e.push(' name="',u(f.name),'"');if(f.type){e.push(' type="',u(f.type),'"');var w={};I(w,f);delete w.type;f=w}e.push(">");e=e.join("")}e=g.createElement(e);f&&("string"==typeof f?e.className=f:"array"==n(f)?e.className=f.join(" "):ba(e,f));2<c.length&&da(g,e,c);return e} ...
# processGoogleToken({"newToken":"AOhZihtcAUQdSKjQmy149Rl-26XZYsjMVx_8qA5AMNzyujvz1ojKlmcGTg","validLifetimeSecs":300,"freshLifetimeSecs":300,"1p_jar":"2018-10-29-14","pucrd":"CgwIABAAGAMgACgAOAF4Aw"});
